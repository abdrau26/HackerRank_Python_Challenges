# %% [markdown]
# ![image.png](attachment:8a588c7b-f7fa-4cde-9588-0fd1764f28cb.png)

# %% [markdown]
# # Solution

# %%
def solve(s):
    lst = s.split()
    temp = []
    for word in lst:
        temp.append(word.capitalize())
        temp.append(" ")
    return "".join(temp[:-1])
        

if __name__ == '__main__':
    nameString = input()
    sol =solve(nameString)
    print(sol)
# Out:
#  abdul 12rauff
# Abdul 12rauff
