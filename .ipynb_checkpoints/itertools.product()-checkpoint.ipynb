# %% [markdown]
# # Problem Statement

# %% [markdown]
# ![image.png](attachment:24b35743-768f-4545-87d7-b06415229d31.png)

# %% [markdown]
# # Solution:

# %%
from itertools import product
X=list(map(int,input().split()))
Y=list(map(int,input().split()))
prod = list(product(X,Y))
for i in prod:
    print(i, end=" ")
# Out:
#  1 2
#  3 4
# (1, 3) (1, 4) (2, 3) (2, 4)
